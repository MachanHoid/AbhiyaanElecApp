# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
op1 = open("partc_decode_binary_data", 'r')
op2 = open("partc_decode_graycode_data", 'r')

val1 = list(map(int, op1.read().split()))
val2 = list(map(int, op2.read().split()))

# %%
plt.plot(val1);

# %%
plt.plot(val2);
