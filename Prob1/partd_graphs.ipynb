# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
op1 = open("partd_dataset_fault1.txt", 'r')
op2 = open("partd_dataset_fault2.txt", 'r')
# e1 = open("partd_encoded_fault1.txt", 'r')
# e2 = open("partd_encoded_fault2.txt", 'r')

val1 = list(map(int, op1.read().split()))
val2 = list(map(int, op2.read().split()))

# val3 = list(map(int, e1.read().split()))
# val4 = list(map(int, e2.read().split()))

# %%
plt.plot(val1);

# %%
plt.plot(val2);

# %% [markdown]
# Trying to check if there are some intermediate readings that happen when not all contact pins contact at the same time (if we do not use gray codes in the encoder). So I have tried to eliminate those values and plot the remaining values.

# %%
absolute_error_limit = 50
val2_processed = []
prev_val = val2[0]
for i in range(1, len(val2)):
    if abs(prev_val - val2[i]) < absolute_error_limit:
        val2_processed.append(val2[i])
        prev_val = val2[i]

# %%
plt.plot(val2_processed);

# %% [markdown]
# Still this does not look like convincing data, and I do not feel like this is the error we are looking for.
